# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("../data/input/exchange_rate.csv", encoding = 'SHIFT_JIS' ,header = 2,index_col = 0)

# %%
plt.figure(figsize = (12,6))
plt.plot(df.iloc[-100:,0])
plt.savefig('../data/output/exchange_rate_recent_100days.png')
